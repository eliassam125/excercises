# %% [markdown]
# First we load the packeges that we are gonna use:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# now we load the data that hasn't been cleaned

# %%
data_set = pd.read_csv("unclean_data.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data_set = pd.read_csv("unclean_data.csv")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# here we see it has an error that the we can't decode this for fixing this I'll try using a package that will allow us to know
# what type of decode to use:

# %%
import charset_normalizer
with open("unclean_data.csv", 'rb') as rawdata:
    result = charset_normalizer.detect(rawdata.read(5000))


print(result)
# Out:
# {'encoding': 'windows-1250', 'language': 'English', 'confidence': 1.0}

# %% [markdown]
# As we can see it's encoded with windows-1250

# %%
data_set = pd.read_csv("unclean_data.csv", encoding='Windows-1250')

# look at the first few lines
data_set.head(13)
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 0                                     Avatar?˙                     723
# 1   Pirates of the Caribbean: At World's End?˙                     302
# 2                                    Spectre?˙                     602
# 3                      The Dark Knight Rises?˙                     813
# 4                                John Carter?˙                     462
# 5                               Spider-Man 3?˙                     392
# 6                                    Tangled?˙                     324
# 7                    Avengers: Age of Ultron?˙                     635
# 8                    Avengers: Age of Ultron?˙                     635
# 9     Harry Potter and the Half-Blood Prince?˙                     375
# 10        Batman v Superman: Dawn of Justice?˙                     673
# 11                          Superman Returns?˙                     434
# ...
